# %% [markdown]
# # **Matplotlib**

# %%
# %matplotlib inline
from wordcloud import WordCloud
wcloud = WordCloud('../data/D2Coding.ttf',relative_scaling = 0.2).generate("Test Code Test Python")

import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
plt.imshow(wcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# # **Konlpy**

# %%
text = '민병삼 대령의 항명행위로 초치했다'
from konlpy.tag import Okt
twitter = Okt()
print(twitter.pos(text, stem=True))
# Out:
# [('민병삼', 'Noun'), ('대령', 'Noun'), ('의', 'Josa'), ('항', 'Noun'), ('명', 'Suffix'), ('행위', 'Noun'), ('로', 'Josa'), ('초치', 'Noun'), ('하다', 'Verb')]

# %% [markdown]
# ## **nltk**

# %%
# Token
text = " Don't hesitate to ask questions"

# Penn Treebank Corpus 에 따른 기준을 사용하여, 문법별로 나눈다
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
token     = tokenizer.tokenize(text)
print(token)
# Out:
# ['Do', "n't", 'hesitate', 'to', 'ask', 'questions']

# %%
from nltk.corpus import wordnet as wn
wn.synsets('dog')
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01'),
#  Synset('chase.v.01')]

# %%
# pip install -U nltk
# python -m nltk.downloader 'popular'
# pip install -U pywsd

sent = 'I went to the bank to deposit my money'
ambiguous = 'bank'

from pywsd.lesk import simple_lesk
answer = simple_lesk(sent, ambiguous, pos='n')
answer
# Out:
# Warming up PyWSD (takes ~10 secs)... took 2.835926055908203 secs.
# Synset('depository_financial_institution.n.01')
